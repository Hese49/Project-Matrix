# %% [markdown]
# # Project_matrix — Introduction
# *Heikki Miettinen 2026 (AI assisted)*
#
#
# This notebook introduces the overall structure and goals of the Project_matrix module.
#
# 👉 **Take away:** The central idea is to understand **how partial differential equations (PDE) can be transformed into matrix problems**.
#
# ✅ **Big picture: Linear algebra** provides a unifying framework for **analysis, computation, and interpretation**.
#
#
# ## What you will learn
#
# - How PDEs are discretized
# - How matrices arise naturally
# - How numerical methods solve these systems
# - How linear algebra reveals deeper structure
#
#
# ## Structure of the module
#
# 1. Heat equation (A–D)
# 2. Wave equation
# 3. Poisson equation
# 4. 2D Poisson equation
# 5. Iterative solvers
# 6. Sparse matrices and Efficiency
# 7. Schrödinger equation
#
# 👉 Each notebook builds on the previous ones, forming a coherent learning path.
#
#
# ## Guiding principle
#
# The goal is not only to compute solutions, but to understand structure.
#
# ✅ The key transformation is:
#
# #### PDE → Discretization → Matrix → Linear Algebra Insight
